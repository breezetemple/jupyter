# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif']='SimHei'

# %%
df = pd.read_csv('/data/opensourcecode/redmine-analysis/issues.csv', encoding='gb2312')

# %%
df.head()
# Out:
#         #                      项目  跟踪       父任务   状态 优先级  \
# 0  256199  BU1-SDK-1812-01-TAURUS  结点       NaN  已关闭  普通
# 1  256189  BU1-SDK-1812-01-TAURUS  错误       NaN  已确认  普通
# 2  256184  BU1-SDK-1812-01-TAURUS  错误       NaN  已关闭  普通
# 3  256183  BU1-SDK-1812-01-TAURUS  错误       NaN   新建  普通
# 4  256175  BU1-SDK-1812-01-TAURUS  错误  256138.0  已确认  普通
#
#                                                   主题     作者    指派给  \
# 0                                     taurus_rc2方案配置  G 葛长青  G 葛长青
# 1               DLNA或SAT2IP，电视切换到加密节目，一直显示缓冲中，没有相应提示   H 胡春   H 胡春
# 2                       sirius 6613H2-NNE方案search 死机   W 王震   W 王震
# 3                SDK_v2.3.0 gx6605s-combo 软件方案第一轮自测试  G 葛长青  W 吴卫锋
# 4  gx6613H2长时间的系统拷机、播放或其他操作后，网络模块wifi经常自动断开，进入wif...  G 葛长青   L 冷静
#
#                 更新于  ...              结束日期        相关的问题 出现频率  严重性  处理状况   难度  \
# 0  2020-05-18 20:50  ...  2020-05-18 20:50          NaN  NaN  NaN   NaN  NaN
# ...

# %%
df.groupby(['指派给', '状态'])['指派给'].count().unstack().fillna(0).plot.bar()
